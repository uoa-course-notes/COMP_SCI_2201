# %% [markdown]
# ##### <font color='orange'>**Graph Representations**</font>

# %%
# G = (V, E)
# We can use tuples to represent a graph

# %%
from collections import namedtuple

# %%
# arg[0]
# arg[1]: names of the components of our graph
Graph = namedtuple("Graph", ["nodes", "edges"])

# %% [markdown]
# Not the best representation as it is very inefficient compared to the two that we will introduce.

# %%
nodes = ["A", "B", "C", "D"]
edges = [
    ("A", "B"),
    ("A", "B"),
    ("A", "C"),
    ("A", "C"),
    ("A", "D"),
    ("A", "D"),
    ("B", "D"),
    ("C", "D")
]

# %%
G = Graph(nodes, edges)

# %% [markdown]
# ##### <font color='pink'>**Adjacency List**</font>

# %% [markdown]
# Below is the adjacency list representation of the Königsberg's graph problem! <br>
# A: B, B, C, C, D <br>
# B: A, A, D  <br>
# C: A, A, D  <br>
# D: A, B, C  <br>

# %%
def adjacency_dict(G):
    """
    Returns the adjacency list representation of given graph 'G'
    """ 
    
    
    Adj = {node: [] for node in G.nodes()}
    for edge in G.edges:
        node1, node2 = edge[0], edge[1]
        Adj[node1].apend(node1)
        Adj[node2].apend(node2)
    return Adj

# %%
adjacency_dict(G)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 adjacency_dict(G)
#
# Cell In[16], line 7, in adjacency_dict(G)
#       1 def adjacency_dict(G):
#       2     """
#       3     Returns the adjacency list representation of given graph 'G'
#       4     """
# ----> 7     Adj = {node: [] for node in G.nodes()}
#       8     for edge in G.edges:
#       9         node1, node2 = edge[0], edge[1]
#
# TypeError: 'list' object is not callable
