# %% [markdown]
# #### Representing bridges

# %%
BRIDGES = [
    "AaB",
    "AbB",
    "AcC",
    "AdC",
    "AeD",
    "BfD",
    "CgD",
    ]

# %%
def get_walks_starting_from(area, bridges=BRIDGES):
    walks = []
    
    # Call make_walks recursively to build walks starting from a given area.
    # area: initial area that we start from
    # walked: all the paths that we have walke dup to that point that we are in that given area.
    # bridges_crossed: all the bridges that we have crossed to that point that we are in that given area
    def make_walks(area, walked=None, bridges_crossed=None):
        walked = walked or area 
        bridges_crossed = bridges_crossed or ()
        
        # Get all of the bridges connected to `area` that haven't been crossed

# %% [markdown]
# ##### Representing Walks in our program

# %%
"CcAaBbAdCgDeA"
